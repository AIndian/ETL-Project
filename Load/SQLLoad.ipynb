# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from config import code
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-d7cf053bcd25> in <module>
#       2 from sqlalchemy import create_engine
#       3 from sqlalchemy_utils import database_exists, create_database
# ----> 4 from config import code
#
# ImportError: cannot import name 'code' from 'config' (C:\Users\amolk\.conda\envs\PythonData\lib\site-packages\config\__init__.py)

# %%
dia_file = '../finance/DIAdata.csv'
dia_df = pd.read_csv(dia_file)
dia_df = dia_df.drop(dia_df.columns[0], axis=1).set_index('date')
dia_df
# Out:
#             adj. close   close        vol
# date
# 2021-04-15    340.4400  340.44   14137406
# 2021-04-09    337.8600  337.86   16978370
# 2021-04-01    331.4500  331.45   19469474
# 2021-03-26    330.6100  330.61   25489452
# 2021-03-19    326.0100  326.01   23089323
# ...                ...     ...        ...
# 2009-02-06     62.1446   82.86  144429541
# 2009-01-30     60.0596   80.08  120352185
# 2009-01-23     60.3896   80.52  156572069
# 2009-01-16     62.0171   82.69  173149501
# 2009-01-09     64.4949   86.14  144170225
#
# [641 rows x 3 columns]

# %%
EO_file = '../all_df.csv'
EO_df = pd.read_csv(EO_file)
EO_df = EO_df.drop(EO_df.columns[[0]], axis=1)
EO_df=EO_df.set_index('signing_date')
EO_df
# Out:
#              signer    citation document_number  end_page  \
# signing_date
# 2017-01-17    Obama  82 FR 8115      2017-01623      8129
# 2017-01-13    Obama  82 FR 7619      2017-01487      7620
# 2017-01-13    Obama  82 FR 7621      2017-01489      7622
# 2017-01-13    Obama  82 FR 5331      2017-01197      5333
# 2017-01-12    Obama  82 FR 5321      2017-01164      5322
# ...             ...         ...             ...       ...
# 2021-01-20    Biden  86 FR 7029      2021-01762      7035
# 2021-01-20    Biden  86 FR 7037      2021-01765      7043
# 2021-01-20    Biden  86 FR 7045      2021-01766      7048
# 2021-01-20    Biden  86 FR 7049      2021-01767      7050
# 2021-01-20    Biden  86 FR 7051      2021-01768      7052
#
#                                                        html_url  \
# signing_date
# 2017-01-17    https://www.federalregister.gov/documents/2017...
# 2017-01-13    https://www.federalregister.gov/documents/2017...
# 2017-01-13    https://www.federalregister.gov/documents/2017...
# 2017-01-13    https://www.federalregister.gov/documents/2017...
# 2017-01-12    https://www.federalregister.gov/documents/2017...
# ...                                                         ...
# 2021-01-20    https://www.federalregister.gov/documents/2021...
# 2021-01-20    https://www.federalregister.gov/documents/2021...
# 2021-01-20    https://www.federalregister.gov/documents/2021...
# 2021-01-20    https://www.federalregister.gov/documents/2021...
# 2021-01-20    https://www.federalregister.gov/documents/2021...
#
#                                                         pdf_url  \
# signing_date
# 2017-01-17    https://www.govinfo.gov/content/pkg/FR-2017-01...
# 2017-01-13    https://www.govinfo.gov/content/pkg/FR-2017-01...
# 2017-01-13    https://www.govinfo.gov/content/pkg/FR-2017-01...
# 2017-01-13    https://www.govinfo.gov/content/pkg/FR-2017-01...
# 2017-01-12    https://www.govinfo.gov/content/pkg/FR-2017-01...
# ...                                                         ...
# 2021-01-20    https://www.govinfo.gov/content/pkg/FR-2021-01...
# 2021-01-20    https://www.govinfo.gov/content/pkg/FR-2021-01...
# 2021-01-20    https://www.govinfo.gov/content/pkg/FR-2021-01...
# 2021-01-20    https://www.govinfo.gov/content/pkg/FR-2021-01...
# 2021-01-20    https://www.govinfo.gov/content/pkg/FR-2021-01...
#
#                                type          subtype publication_date  \
# signing_date
# 2017-01-17    Presidential Document  Executive Order          1/23/17
# 2017-01-13    Presidential Document  Executive Order          1/19/17
# 2017-01-13    Presidential Document  Executive Order          1/19/17
# 2017-01-13    Presidential Document  Executive Order          1/18/17
# 2017-01-12    Presidential Document  Executive Order          1/17/17
# ...                             ...              ...              ...
# 2021-01-20    Presidential Document  Executive Order          1/25/21
# 2021-01-20    Presidential Document  Executive Order          1/25/21
# 2021-01-20    Presidential Document  Executive Order          1/25/21
# 2021-01-20    Presidential Document  Executive Order          1/25/21
# 2021-01-20    Presidential Document  Executive Order          1/25/21
#
#               start_page                                              title  \
# signing_date
# 2017-01-17          8115  Amending the Civil Service Rules, Executive Or...
# 2017-01-13          7619  Providing an Order of Succession Within the De...
# 2017-01-13          7621  Providing an Order of Succession Within the En...
# 2017-01-13          5331  Recognizing Positive Actions by the Government...
# 2017-01-12          5321  Amending Executive Order 11016 To Update Eligi...
# ...                  ...                                                ...
# 2021-01-20          7029   Ethics Commitments by Executive Branch Personnel
# 2021-01-20          7037  Protecting Public Health and the Environment a...
# 2021-01-20          7045  Protecting the Federal Workforce and Requiring...
# 2021-01-20          7049  Revocation of Certain Executive Orders Concern...
# 2021-01-20          7051  Revision of Civil Immigration Enforcement Poli...
#
#                                               disposition_notes  \
# signing_date
# 2017-01-17    Amends: EO 13467, June 30, 2008; EO 13488, Jan...
# 2017-01-13    Revokes: EO 13557, November 4, 2010\nRevoked b...
# 2017-01-13                   Revokes: EO 13737, August 12, 2016
# 2017-01-13    Revokes in part: EO 13067, November 3, 1997\nR...
# 2017-01-12                     Amends: EO 11016, April 25, 1962
# ...                                                         ...
# 2021-01-20                                                  NaN
# 2021-01-20                                                  NaN
# 2021-01-20                                                  NaN
# 2021-01-20                                                  NaN
# 2021-01-20                                                  NaN
#
#               executive_order_number
# signing_date
# 2017-01-17                     13764
# 2017-01-13                     13762
# 2017-01-13                     13763
# 2017-01-13                     13761
# 2017-01-12                     13758
# ...                              ...
# 2021-01-20                     13989
# 2021-01-20                     13990
# 2021-01-20                     13991
# 2021-01-20                     13992
# 2021-01-20                     13993
#
# [535 rows x 13 columns]

# %%
EA_file = '../Main/appointments.csv'
EA_df = pd.read_csv(EA_file)
EA_df = EA_df.drop(EA_df.columns[[0, 1]], axis=1)
EA_df = EA_df.set_index('Service Start')
EA_df
# Out:
#               President Service End             Cabinet Appointment  \
# Service Start
# 2009-01-20        Obama  2017-01-20                       President
# 2009-01-20        Obama  2017-01-20                  Vice President
# 2009-01-21        Obama  2013-02-01              Secretary of State
# 2013-02-01        Obama  2017-01-20              Secretary of State
# 2009-01-26        Obama  2013-01-25           Secretary of Treasury
# ...                 ...         ...                             ...
# 2017-01-20        Trump  2017-07-31  Secretary of Homeland Security
# 2017-07-31        Trump  2017-12-06  Secretary of Homeland Security
# 2017-12-06        Trump  2019-04-10  Secretary of Homeland Security
# 2019-04-11        Trump  2019-11-13  Secretary of Homeland Security
# 2019-11-13        Trump         NaN  Secretary of Homeland Security
#
#                  Appointee Name
# Service Start
# 2009-01-20         Barack Obama
# 2009-01-20            Joe Biden
# 2009-01-21      Hillary Clinton
# 2013-02-01           John Kerry
# 2009-01-26         Tim Geithner
# ...                         ...
# 2017-01-20        John F. Kelly
# 2017-07-31          Elaine Duke
# 2017-12-06     Kirstjen Nielsen
# 2019-04-11      Kevin McAleenan
# 2019-11-13            Chad Wolf
#
# [75 rows x 4 columns]

# %%
connection_string = f"postgres:2799@localhost:5432/presfin_db"
engine = create_engine(f'postgresql://{connection_string}', echo= True)

# %%
if not database_exists(engine.url):
    create_database(engine.url)
else:
    # Connect the database if exists.
    engine.connect()

# %%
dia_df.to_sql(name='DIA stock', con=engine, if_exists='replace', index=True)
EO_df.to_sql(name='orders', con=engine, if_exists='replace', index=True)
EA_df.to_sql(name='appointments', con=engine, if_exists='replace', index=True)
# Out:
# 2021-04-17 10:19:52,709 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-04-17 10:19:52,710 INFO sqlalchemy.engine.Engine [cached since 266.4s ago] {'name': 'DIA stock'}
# 2021-04-17 10:19:52,712 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-04-17 10:19:52,714 INFO sqlalchemy.engine.Engine [cached since 266.4s ago] {'name': 'DIA stock'}
# 2021-04-17 10:19:52,717 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-04-17 10:19:52,719 INFO sqlalchemy.engine.Engine [cached since 266.4s ago] {'schema': 'public'}
# 2021-04-17 10:19:52,723 INFO sqlalchemy.engine.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-04-17 10:19:52,725 INFO sqlalchemy.engine.Engine [generated in 0.00163s] {'table_name': 'DIA stock'}
# 2021-04-17 10:19:52,729 INFO sqlalchemy.engine.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (
#                 SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                 WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                 AND a.atthasdef
#               ) AS DEFAULT,
#               a.attnotnull,
#               a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated,
#                               (SELECT json_build_object(
#                     'always', a.attidentity = 'a',
#                     'start', s.seqstart,
#                     'increment', s.seqincrement,
#                     'minvalue', s.seqmin,
#                     'maxvalue', s.seqmax,
#                     'cache', s.seqcache,
#                     'cycle', s.seqcycle)
#                 FROM pg_catalog.pg_sequence s
#                 JOIN pg_catalog.pg_class c on s.seqrelid = c."oid"
#                 WHERE c.relkind = 'S'
#                 AND a.attidentity != ''
#                 AND s.seqrelid = pg_catalog.pg_get_serial_sequence(
#                     a.attrelid::regclass::text, a.attname
#                 )::regclass::oid
#                 ) as identity_options
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-04-17 10:19:52,730 INFO sqlalchemy.engine.Engine [generated in 0.00182s] {'table_oid': 24770}
# 2021-04-17 10:19:52,735 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-04-17 10:19:52,736 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {}
# 2021-04-17 10:19:52,738 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-04-17 10:19:52,738 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {}
# 2021-04-17 10:19:52,742 INFO sqlalchemy.engine.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-04-17 10:19:52,744 INFO sqlalchemy.engine.Engine [generated in 0.00112s] {'table_oid': 24770}
# 2021-04-17 10:19:52,746 INFO sqlalchemy.engine.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-04-17 10:19:52,746 INFO sqlalchemy.engine.Engine [generated in 0.00060s] {'table_oid': 24770}
# 2021-04-17 10:19:52,752 INFO sqlalchemy.engine.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-04-17 10:19:52,753 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {'table': 24770}
# 2021-04-17 10:19:52,755 INFO sqlalchemy.engine.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   pg_get_expr(ix.indpred, ix.indrelid),
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-04-17 10:19:52,756 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {'table_oid': 24770}
# 2021-04-17 10:19:52,762 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-04-17 10:19:52,764 INFO sqlalchemy.engine.Engine [generated in 0.00218s] {'table_oid': 24770}
# 2021-04-17 10:19:52,767 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
# 2021-04-17 10:19:52,768 INFO sqlalchemy.engine.Engine [generated in 0.00104s] {'table_oid': 24770}
# 2021-04-17 10:19:52,770 INFO sqlalchemy.engine.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-04-17 10:19:52,771 INFO sqlalchemy.engine.Engine [generated in 0.00096s] {'table_oid': 24770}
# 2021-04-17 10:19:52,773 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:52,774 INFO sqlalchemy.engine.Engine
# DROP TABLE "DIA stock"
# 2021-04-17 10:19:52,774 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2021-04-17 10:19:52,789 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:52,797 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:52,798 INFO sqlalchemy.engine.Engine
# CREATE TABLE "DIA stock" (
# 	date TEXT,
# 	"adj. close" FLOAT(53),
# 	close FLOAT(53),
# 	vol BIGINT
# )
#
#
# 2021-04-17 10:19:52,798 INFO sqlalchemy.engine.Engine [no key 0.00074s] {}
# 2021-04-17 10:19:52,805 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_DIA stock_date" ON "DIA stock" (date)
# 2021-04-17 10:19:52,806 INFO sqlalchemy.engine.Engine [no key 0.00063s] {}
# 2021-04-17 10:19:52,808 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:52,811 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:52,819 INFO sqlalchemy.engine.Engine INSERT INTO "DIA stock" (date, "adj. close", close, vol) VALUES (%(date)s, %(adj. close)s, %(close)s, %(vol)s)
# 2021-04-17 10:19:52,820 INFO sqlalchemy.engine.Engine [generated in 0.00663s] ({'date': '2021-04-15', 'adj. close': 340.44, 'close': 340.44, 'vol': 14137406}, {'date': '2021-04-09', 'adj. close': 337.86, 'close': 337.86, 'vol': 16978370}, {'date': '2021-04-01', 'adj. close': 331.45, 'close': 331.45, 'vol': 19469474}, {'date': '2021-03-26', 'adj. close': 330.61, 'close': 330.61, 'vol': 25489452}, {'date': '2021-03-19', 'adj. close': 326.01, 'close': 326.01, 'vol': 23089323}, {'date': '2021-03-12', 'adj. close': 327.6352, 'close': 328.31, 'vol': 30535893}, {'date': '2021-03-05', 'adj. close': 314.5921, 'close': 315.24, 'vol': 29570718}, {'date': '2021-02-26', 'adj. close': 308.814, 'close': 309.45, 'vol': 28128447}  ... displaying 10 of 641 total bound parameter sets ...  {'date': '2009-01-16', 'adj. close': 62.0171, 'close': 82.69, 'vol': 173149501}, {'date': '2009-01-09', 'adj. close': 64.4949, 'close': 86.14, 'vol': 144170225})
# 2021-04-17 10:19:52,836 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:52,838 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-04-17 10:19:52,838 INFO sqlalchemy.engine.Engine [cached since 266.5s ago] {'schema': 'public'}
# 2021-04-17 10:19:52,843 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-04-17 10:19:52,843 INFO sqlalchemy.engine.Engine [cached since 266.6s ago] {'name': 'orders'}
# 2021-04-17 10:19:52,845 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-04-17 10:19:52,846 INFO sqlalchemy.engine.Engine [cached since 266.6s ago] {'name': 'orders'}
# 2021-04-17 10:19:52,847 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-04-17 10:19:52,848 INFO sqlalchemy.engine.Engine [cached since 266.5s ago] {'schema': 'public'}
# 2021-04-17 10:19:52,850 INFO sqlalchemy.engine.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-04-17 10:19:52,850 INFO sqlalchemy.engine.Engine [cached since 0.1277s ago] {'table_name': 'orders'}
# 2021-04-17 10:19:52,852 INFO sqlalchemy.engine.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (
#                 SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                 WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                 AND a.atthasdef
#               ) AS DEFAULT,
#               a.attnotnull,
#               a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated,
#                               (SELECT json_build_object(
#                     'always', a.attidentity = 'a',
#                     'start', s.seqstart,
#                     'increment', s.seqincrement,
#                     'minvalue', s.seqmin,
#                     'maxvalue', s.seqmax,
#                     'cache', s.seqcache,
#                     'cycle', s.seqcycle)
#                 FROM pg_catalog.pg_sequence s
#                 JOIN pg_catalog.pg_class c on s.seqrelid = c."oid"
#                 WHERE c.relkind = 'S'
#                 AND a.attidentity != ''
#                 AND s.seqrelid = pg_catalog.pg_get_serial_sequence(
#                     a.attrelid::regclass::text, a.attname
#                 )::regclass::oid
#                 ) as identity_options
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-04-17 10:19:52,853 INFO sqlalchemy.engine.Engine [cached since 0.1243s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,855 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-04-17 10:19:52,856 INFO sqlalchemy.engine.Engine [cached since 0.1205s ago] {}
# 2021-04-17 10:19:52,858 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-04-17 10:19:52,858 INFO sqlalchemy.engine.Engine [cached since 0.1208s ago] {}
# 2021-04-17 10:19:52,861 INFO sqlalchemy.engine.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-04-17 10:19:52,862 INFO sqlalchemy.engine.Engine [cached since 0.1197s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,863 INFO sqlalchemy.engine.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-04-17 10:19:52,864 INFO sqlalchemy.engine.Engine [cached since 0.118s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,865 INFO sqlalchemy.engine.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
# 2021-04-17 10:19:52,866 INFO sqlalchemy.engine.Engine [cached since 0.1128s ago] {'table': 24777}
# 2021-04-17 10:19:52,867 INFO sqlalchemy.engine.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   pg_get_expr(ix.indpred, ix.indrelid),
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-04-17 10:19:52,867 INFO sqlalchemy.engine.Engine [cached since 0.112s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,870 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-04-17 10:19:52,870 INFO sqlalchemy.engine.Engine [cached since 0.1086s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,872 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-04-17 10:19:52,872 INFO sqlalchemy.engine.Engine [cached since 0.1051s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,905 INFO sqlalchemy.engine.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-04-17 10:19:52,905 INFO sqlalchemy.engine.Engine [cached since 0.1361s ago] {'table_oid': 24777}
# 2021-04-17 10:19:52,906 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:52,907 INFO sqlalchemy.engine.Engine
# DROP TABLE orders
# 2021-04-17 10:19:52,907 INFO sqlalchemy.engine.Engine [no key 0.00063s] {}
# 2021-04-17 10:19:52,912 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:52,917 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:52,919 INFO sqlalchemy.engine.Engine
# CREATE TABLE orders (
# 	index BIGINT,
# 	signer TEXT,
# 	citation TEXT,
# 	document_number TEXT,
# 	end_page BIGINT,
# 	html_url TEXT,
# 	pdf_url TEXT,
# 	type TEXT,
# 	subtype TEXT,
# 	publication_date TEXT,
# 	signing_date TEXT,
# 	start_page BIGINT,
# 	title TEXT,
# 	disposition_notes TEXT,
# 	executive_order_number BIGINT
# )
#
#
# 2021-04-17 10:19:52,919 INFO sqlalchemy.engine.Engine [no key 0.00036s] {}
# 2021-04-17 10:19:52,926 INFO sqlalchemy.engine.Engine CREATE INDEX ix_orders_index ON orders (index)
# 2021-04-17 10:19:52,927 INFO sqlalchemy.engine.Engine [no key 0.00062s] {}
# 2021-04-17 10:19:52,930 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:52,933 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:52,944 INFO sqlalchemy.engine.Engine INSERT INTO orders (index, signer, citation, document_number, end_page, html_url, pdf_url, type, subtype, publication_date, signing_date, start_page, title, disposition_notes, executive_order_number) VALUES (%(index)s, %(signer)s, %(citation)s, %(document_number)s, %(end_page)s, %(html_url)s, %(pdf_url)s, %(type)s, %(subtype)s, %(publication_date)s, %(signing_date)s, %(start_page)s, %(title)s, %(disposition_notes)s, %(executive_order_number)s)
# 2021-04-17 10:19:52,945 INFO sqlalchemy.engine.Engine [generated in 0.01078s] ({'index': 0, 'signer': 'Obama', 'citation': '82 FR 8115', 'document_number': '2017-01623', 'end_page': 8129, 'html_url': 'https://www.federalregister.gov/documents/2017/01/23/2017-01623/amending-the-civil-service-rules-executive-order-13488-and-executive-order-13467-to-modernize-the', 'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-01-23/pdf/2017-01623.pdf', 'type': 'Presidential Document', 'subtype': 'Executive Order', 'publication_date': '1/23/17', 'signing_date': '2017-01-17', 'start_page': 8115, 'title': 'Amending the Civil Service Rules, Executive Order 13488, and Executive Order 13467 To Modernize the Executive Branch-Wide Governance Structure and Processes for Security Clearances, Suitability and Fitness for Employment, and Credentialing, and Related Matters', 'disposition_notes': 'Amends: EO 13467, June 30, 2008; EO 13488, January 16, 2009', 'executive_order_number': 13764}, {'index': 1, 'signer': 'Obama', 'citation': '82 FR 7619', 'document_number': '2017-01487', 'end_page': 7620, 'html_url': 'https://www.federalregister.gov/documents/2017/01/19/2017-01487/providing-an-order-of-succession-within-the-department-of-justice', 'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-01-19/pdf/2017-01487.pdf', 'type': 'Presidential Document', 'subtype': 'Executive Order', 'publication_date': '1/19/17', 'signing_date': '2017-01-13', 'start_page': 7619, 'title': 'Providing an Order of Succession Within the Department of Justice', 'disposition_notes': 'Revokes: EO 13557, November 4, 2010\nRevoked by: EO 13775, February 9, 2017', 'executive_order_number': 13762}, {'index': 2, 'signer': 'Obama', 'citation': '82 FR 7621', 'document_number': '2017-01489', 'end_page': 7622, 'html_url': 'https://www.federalregister.gov/documents/2017/01/19/2017-01489/providing-an-order-of-succession-within-the-environmental-protection-agency', 'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-01-19/pdf/2017-01489.pdf', 'type': 'Presidential Document', 'subtype': 'Executive Order', 'publication_date': '1/19/17', 'signing_date': '2017-01-13', 'start_page': 7621, 'title': 'Providing an Order of Succession Within the Environmental Protection Agency', 'disposition_notes': 'Revokes: EO 13737, August 12, 2016', 'executive_order_number': 13763}, {'index': 3, 'signer': 'Obama', 'citation': '82 FR 5331', 'document_number': '2017-01197', 'end_page': 5333, 'html_url': 'https://www.federalregister.gov/documents/2017/01/18/2017-01197/recognizing-positive-actions-by-the-government-of-sudan-and-providing-for-the-revocation-of-certain', 'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-01-18/pdf/2017-01197.pdf', 'type': 'Presidential Document', 'subtype': 'Executive Order', 'publication_date': '1/18/17', 'signing_date': '2017-01-13', 'start_page': 5331, 'title': 'Recognizing Positive Actions by the Government of Sudan and Providing for the Revocation of Certain Sudan-Related Sanctions', 'disposition_notes': 'Revokes in part: EO 13067, November 3, 1997\nRevokes: EO 13412, October 13, 2006\nAmended by: EO 13804, July 11, 2017', 'executive_order_number': 13761}, {'index': 4, 'signer': 'Obama', 'citation': '82 FR 5321', 'document_number': '2017-01164', 'end_page': 5322, 'html_url': 'https://www.federalregister.gov/documents/2017/01/17/2017-01164/amending-executive-order-11016-to-update-eligibility-criteria-for-award-of-the-purple-heart', 'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-01-17/pdf/2017-01164.pdf', 'type': 'Presidential Document', 'subtype': 'Executive Order', 'publication_date': '1/17/17', 'signing_date': '2017-01-12', 'start_page': 5321, 'title': 'Amending Executive Order 11016 To Update Eligibility Criteria for Award of the Purple Heart', 'disposition_notes': 'Amends: EO 11016, April 25, 1962', 'executive_order_number': 13758}, {'index': 5, 'signer': 'Obama', 'citation': '82 FR 5323', 'document_number': '2017-01168', 'end_page': 5324, 'html_url': 'h ...
# 2021-04-17 10:19:52,969 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:52,972 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-04-17 10:19:52,973 INFO sqlalchemy.engine.Engine [cached since 266.7s ago] {'name': 'appointments'}
# 2021-04-17 10:19:52,974 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-04-17 10:19:52,975 INFO sqlalchemy.engine.Engine [cached since 266.7s ago] {'name': 'appointments'}
# 2021-04-17 10:19:52,976 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-04-17 10:19:52,976 INFO sqlalchemy.engine.Engine [cached since 266.7s ago] {'schema': 'public'}
# 2021-04-17 10:19:52,978 INFO sqlalchemy.engine.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-04-17 10:19:52,979 INFO sqlalchemy.engine.Engine [cached since 0.2555s ago] {'table_name': 'appointments'}
# 2021-04-17 10:19:52,980 INFO sqlalchemy.engine.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (
#                 SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                 WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                 AND a.atthasdef
#               ) AS DEFAULT,
#               a.attnotnull,
#               a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated,
#                               (SELECT json_build_object(
#                     'always', a.attidentity = 'a',
#                     'start', s.seqstart,
#                     'increment', s.seqincrement,
#                     'minvalue', s.seqmin,
#                     'maxvalue', s.seqmax,
#                     'cache', s.seqcache,
#                     'cycle', s.seqcycle)
#                 FROM pg_catalog.pg_sequence s
#                 JOIN pg_catalog.pg_class c on s.seqrelid = c."oid"
#                 WHERE c.relkind = 'S'
#                 AND a.attidentity != ''
#                 AND s.seqrelid = pg_catalog.pg_get_serial_sequence(
#                     a.attrelid::regclass::text, a.attname
#                 )::regclass::oid
#                 ) as identity_options
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-04-17 10:19:52,981 INFO sqlalchemy.engine.Engine [cached since 0.252s ago] {'table_oid': 24784}
# 2021-04-17 10:19:52,983 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-04-17 10:19:52,983 INFO sqlalchemy.engine.Engine [cached since 0.2476s ago] {}
# 2021-04-17 10:19:52,984 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-04-17 10:19:52,985 INFO sqlalchemy.engine.Engine [cached since 0.247s ago] {}
# 2021-04-17 10:19:52,987 INFO sqlalchemy.engine.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-04-17 10:19:52,987 INFO sqlalchemy.engine.Engine [cached since 0.2448s ago] {'table_oid': 24784}
# 2021-04-17 10:19:52,988 INFO sqlalchemy.engine.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-04-17 10:19:52,989 INFO sqlalchemy.engine.Engine [cached since 0.2426s ago] {'table_oid': 24784}
# 2021-04-17 10:19:52,990 INFO sqlalchemy.engine.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-04-17 10:19:52,990 INFO sqlalchemy.engine.Engine [cached since 0.2375s ago] {'table': 24784}
# 2021-04-17 10:19:52,992 INFO sqlalchemy.engine.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   pg_get_expr(ix.indpred, ix.indrelid),
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-04-17 10:19:52,993 INFO sqlalchemy.engine.Engine [cached since 0.2374s ago] {'table_oid': 24784}
# 2021-04-17 10:19:52,995 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-04-17 10:19:52,996 INFO sqlalchemy.engine.Engine [cached since 0.2343s ago] {'table_oid': 24784}
# 2021-04-17 10:19:52,997 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
# 2021-04-17 10:19:52,997 INFO sqlalchemy.engine.Engine [cached since 0.2306s ago] {'table_oid': 24784}
# 2021-04-17 10:19:52,999 INFO sqlalchemy.engine.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-04-17 10:19:52,999 INFO sqlalchemy.engine.Engine [cached since 0.2296s ago] {'table_oid': 24784}
# 2021-04-17 10:19:53,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:53,001 INFO sqlalchemy.engine.Engine
# DROP TABLE appointments
# 2021-04-17 10:19:53,001 INFO sqlalchemy.engine.Engine [no key 0.00042s] {}
# 2021-04-17 10:19:53,007 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:53,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:53,013 INFO sqlalchemy.engine.Engine
# CREATE TABLE appointments (
# 	index BIGINT,
# 	"President" TEXT,
# 	"Service Start" TEXT,
# 	"Service End" TEXT,
# 	"Cabinet Appointment" TEXT,
# 	"Appointee Name" TEXT
# )
#
#
# 2021-04-17 10:19:53,013 INFO sqlalchemy.engine.Engine [no key 0.00055s] {}
# 2021-04-17 10:19:53,020 INFO sqlalchemy.engine.Engine CREATE INDEX ix_appointments_index ON appointments (index)
# 2021-04-17 10:19:53,020 INFO sqlalchemy.engine.Engine [no key 0.00067s] {}
# 2021-04-17 10:19:53,024 INFO sqlalchemy.engine.Engine COMMIT
# 2021-04-17 10:19:53,026 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-04-17 10:19:53,028 INFO sqlalchemy.engine.Engine INSERT INTO appointments (index, "President", "Service Start", "Service End", "Cabinet Appointment", "Appointee Name") VALUES (%(index)s, %(President)s, %(Service Start)s, %(Service End)s, %(Cabinet Appointment)s, %(Appointee Name)s)
# 2021-04-17 10:19:53,029 INFO sqlalchemy.engine.Engine [generated in 0.00167s] ({'index': 0, 'President': 'Obama', 'Service Start': '2009-01-20', 'Service End': '2017-01-20', 'Cabinet Appointment': 'President', 'Appointee Name': 'Barack Obama'}, {'index': 1, 'President': 'Obama', 'Service Start': '2009-01-20', 'Service End': '2017-01-20', 'Cabinet Appointment': 'Vice President', 'Appointee Name': 'Joe Biden'}, {'index': 2, 'President': 'Obama', 'Service Start': '2009-01-21', 'Service End': '2013-02-01', 'Cabinet Appointment': 'Secretary of State', 'Appointee Name': 'Hillary Clinton'}, {'index': 3, 'President': 'Obama', 'Service Start': '2013-02-01', 'Service End': '2017-01-20', 'Cabinet Appointment': 'Secretary of State', 'Appointee Name': 'John Kerry'}, {'index': 4, 'President': 'Obama', 'Service Start': '2009-01-26', 'Service End': '2013-01-25', 'Cabinet Appointment': 'Secretary of Treasury', 'Appointee Name': 'Tim Geithner'}, {'index': 5, 'President': 'Obama', 'Service Start': '2013-02-28', 'Service End': '2017-01-20', 'Cabinet Appointment': 'Secretary of Treasury', 'Appointee Name': 'Jack Lew'}, {'index': 6, 'President': 'Obama', 'Service Start': '2009-01-20', 'Service End': '2011-06-30', 'Cabinet Appointment': 'Secretary of Defense', 'Appointee Name': 'Bob Gates'}, {'index': 7, 'President': 'Obama', 'Service Start': '2011-07-01', 'Service End': '2013-02-26', 'Cabinet Appointment': 'Secretary of Defense', 'Appointee Name': 'Leon Panetta'}  ... displaying 10 of 75 total bound parameter sets ...  {'index': 73, 'President': 'Trump', 'Service Start': '2019-04-11', 'Service End': '2019-11-13', 'Cabinet Appointment': 'Secretary of Homeland Security', 'Appointee Name': 'Kevin McAleenan'}, {'index': 74, 'President': 'Trump', 'Service Start': '2019-11-13', 'Service End': None, 'Cabinet Appointment': 'Secretary of Homeland Security', 'Appointee Name': 'Chad Wolf'})
# 2021-04-17 10:19:53,033 INFO sqlalchemy.engine.Engine COMMIT
